# %% [markdown]
# # Project 2 - Graduate Admission Prediction

# %% [markdown]
# # Using Dataset - 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Data

# %%
data = pd.read_csv("D:\Python Data Science\Graduate Admission Predictions\Admission_Predict_Ver1.1.csv")
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# ## Checking for any Null Values

# %%
data.isnull().any()
# Out:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %% [markdown]
# ## Understanding the Features and Target Attributes

# %%
data.shape
# Out:
# (500, 9)

# %% [markdown]
# ### Checking variable types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# ### Exploring Target Attribute

# %%
data['Chance of Admit '].describe()
# Out:
# count    500.00000
# mean       0.72174
# std        0.14114
# min        0.34000
# 25%        0.63000
# 50%        0.72000
# 75%        0.82000
# max        0.97000
# Name: Chance of Admit , dtype: float64

# %%
sns.displot(data['Chance of Admit '])
plt.title('Distribution of Chances of Admit')
plt.show()

# %% [markdown]
# ### Exploring Feature Attributes

# %%
sns.displot(data['GRE Score'])
plt.title('Distribution of GRE Score')
plt.show()

# %%
sns.displot(data['TOEFL Score'])
plt.title('Distribution of TOEFL Score')
plt.show()

# %%
sns.displot(data['University Rating'])
plt.title('Distribution of University Rating')
plt.show()

# %%
sns.displot(data['SOP'])
plt.title('Distribution of SOP')
plt.show()

# %%
sns.displot(data['LOR '])
plt.title('Distribution of LOR ')
plt.show()

# %%
sns.displot(data['CGPA'])
plt.title('Distribution of CGPA')
plt.show()

# %%
sns.displot(data['Research'])
plt.title('Distribution of Research')
plt.show()

# %%
data['GRE Score'].describe()
# Out:
# count    500.000000
# mean     316.472000
# std       11.295148
# min      290.000000
# 25%      308.000000
# 50%      317.000000
# 75%      325.000000
# max      340.000000
# Name: GRE Score, dtype: float64

# %%
x = ["Worst","Average","Best"]
y = np.array([data["GRE Score"].min(),data["GRE Score"].mean(),data["GRE Score"].max()])
plt.figure(figsize = (10,8))
plt.bar(x,y,color = 'lightblue')
plt.title("GRE Score")
plt.xlabel("Levels of betterness")
plt.ylabel("GRE Score")
plt.show()

# %%
data['TOEFL Score'].describe()
# Out:
# count    500.000000
# mean     107.192000
# std        6.081868
# min       92.000000
# 25%      103.000000
# 50%      107.000000
# 75%      112.000000
# max      120.000000
# Name: TOEFL Score, dtype: float64

# %%
x = ["Worst","Average","Best"]
y = np.array([data["TOEFL Score"].min(),data["TOEFL Score"].mean(),data["TOEFL Score"].max()])
plt.figure(figsize = (10,8))
plt.bar(x,y,color = 'lightblue')
plt.title("TOEFL Score")
plt.xlabel("Levels of betterness")
plt.ylabel("TOEFL Score")
plt.show()

# %%
data['SOP'].describe()
# Out:
# count    500.000000
# mean       3.374000
# std        0.991004
# min        1.000000
# 25%        2.500000
# 50%        3.500000
# 75%        4.000000
# max        5.000000
# Name: SOP, dtype: float64

# %%
x = ["Worst","Average","Best"]
y = np.array([data["SOP"].min(),data["SOP"].mean(),data["SOP"].max()])
plt.figure(figsize = (10,8))
plt.bar(x,y,color = 'lightblue')
plt.title("SOP")
plt.xlabel("Levels of betterness")
plt.ylabel("SOP")
plt.show()

# %%
data['LOR '].describe()
# Out:
# count    500.00000
# mean       3.48400
# std        0.92545
# min        1.00000
# 25%        3.00000
# 50%        3.50000
# 75%        4.00000
# max        5.00000
# Name: LOR , dtype: float64

# %%
x = ["Worst","Average","Best"]
y = np.array([data["LOR "].min(),data["LOR "].mean(),data["LOR "].max()])
plt.figure(figsize = (10,8))
plt.bar(x,y,color = 'lightblue')
plt.title("LOR ")
plt.xlabel("Levels of betterness")
plt.ylabel("LOR ")
plt.show()

# %%
data['CGPA'].describe()
# Out:
# count    500.000000
# mean       8.576440
# std        0.604813
# min        6.800000
# 25%        8.127500
# 50%        8.560000
# 75%        9.040000
# max        9.920000
# Name: CGPA, dtype: float64

# %%
x = ["Worst","Average","Best"]
y = np.array([data["CGPA"].min(),data["CGPA"].mean(),data["CGPA"].max()])
plt.figure(figsize = (10,8))
plt.bar(x,y,color = 'lightblue')
plt.title("CGPA")
plt.xlabel("Levels of betterness")
plt.ylabel("CGPA")
plt.show()

# %%
data['University Rating'].describe()
# Out:
# count    500.000000
# mean       3.114000
# std        1.143512
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: University Rating, dtype: float64

# %%
x = ["Worst","Average","Best"]
y = np.array([data["University Rating"].min(),data["University Rating"].mean(),data["University Rating"].max()])
plt.figure(figsize = (10,8))
plt.bar(x,y,color = 'lightblue')
plt.title("University Rating")
plt.xlabel("Levels of betterness")
plt.ylabel("University Rating")
plt.show()

# %%
s = data[data["Chance of Admit "] >= 0.75]["University Rating"].value_counts()
plt.title("University Ratings of Candidates with an 75% acceptance chance")
s.plot(kind='bar',figsize=(18, 10),color = 'g')
plt.xlabel("University Rating")
plt.ylabel("Candidates")
plt.show()

# %% [markdown]
# ## Plotting ScatterPlot and RegressionPlot

# %%
sns.scatterplot(x="GRE Score",y="TOEFL Score", data=data)
plt.show()

# %%
sns.regplot(x="GRE Score",y="TOEFL Score", data=data)
plt.title("GRE Score Vs TOEFL Score")
plt.show()

# %%
sns.scatterplot(x="GRE Score",y="CGPA", data=data)
plt.show()

# %%
sns.regplot(x="GRE Score",y="CGPA", data=data)
plt.title("GRE Score Vs CGPA")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaled_features = data.copy()
col_names = ['GRE Score', 'TOEFL Score']

# %%
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

# %%
scaled_features[col_names] = features
scaled_features.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X = scaled_features.drop(['Chance of Admit ','Serial No.'], axis=1)
Y = scaled_features['Chance of Admit ']
x_train, x_test, y_train, y_test = train_test_split(X,Y,train_size = 0.80,random_state = 42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (400, 7)
# (100, 7)
# (400,)
# (100,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
#from sklearn.svm import SVR
#from sklearn.linear_model import LinearRegression
#from sklearn.ensemble import AdaBoostRegressor
#from sklearn.ensemble import GradientBoostingRegressor
#from sklearn.linear_model import Lasso,Ridge

import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Linear Regression Model

# %%
lr_model = LinearRegression()
lr_model.fit(x_train,y_train)
lr_predictions = lr_model.predict(x_test)
print("Linear Regression Model Results :")
print("Root Mean Squared Error ->",np.sqrt(mean_squared_error(y_test, lr_predictions)))
print("R-score                 ->",r2_score(y_test,lr_predictions))
print("Mean Absolute Error     ->",mean_absolute_error(y_test,lr_predictions))
# Out:
# Linear Regression Model Results :
# Root Mean Squared Error -> 0.06086588041578314
# R-score                 -> 0.8188432567829627
# Mean Absolute Error     -> 0.04272265427705368

# %%
print("Green Line  -> Test")
print("Orange Line -> Predicted")
fig = plt.figure(figsize = (25,10))
c = [i for i in range(1,101,1)]
plt.plot(c,y_test,color = 'green', linewidth = 2.5, label='Test')
plt.plot(c,lr_predictions, color = 'orange', linewidth = 2.5, label='Predicted')
plt.grid(alpha = 0.4)
plt.legend()
fig.suptitle('Actual vs Predicted',size = 30)
# Out:
# Green Line  -> Test
# Orange Line -> Predicted
# Text(0.5, 0.98, 'Actual vs Predicted')

# %% [markdown]
# # Decision Tree Regressor

# %%
dtr_model = DecisionTreeRegressor()
dtr_model.fit(x_train,y_train)
dtr_predictions = dtr_model.predict(x_test)
print("Linear Regression Model Results :")
print("Root Mean Squared Error ->",np.sqrt(mean_squared_error(y_test,dtr_predictions)))
print("R-score                 ->",r2_score(y_test,dtr_predictions))
print("Mean Absolute Error     ->",mean_absolute_error(y_test,dtr_predictions))
# Out:
# Linear Regression Model Results :
# Root Mean Squared Error -> 0.09309135298189623
# R-score                 -> 0.576234718826406
# Mean Absolute Error     -> 0.0646

# %%
print("Green Line  -> Test")
print("Orange Line -> Predicted")
fig = plt.figure(figsize = (25,10))
c = [i for i in range(1,101,1)]
plt.plot(c,y_test,color = 'green', linewidth = 2.5, label='Test')
plt.plot(c,dtr_predictions, color = 'orange', linewidth = 2.5, label='Predicted')
plt.grid(alpha = 0.4)
plt.legend()
fig.suptitle('Actual vs Predicted',size = 30)
# Out:
# Green Line  -> Test
# Orange Line -> Predicted
# Text(0.5, 0.98, 'Actual vs Predicted')

# %% [markdown]
# # Random Forest Regressor

# %%
rfr_model = RandomForestRegressor()
rfr_model.fit(x_train,y_train)
rfr_predictions = rfr_model.predict(x_test)
print("Linear Regression Model Results :")
print("Root Mean Squared Error ->",np.sqrt(mean_squared_error(y_test,rfr_predictions)))
print("R-score                 ->",r2_score(y_test,rfr_predictions))
print("Mean Absolute Error     ->",mean_absolute_error(y_test,rfr_predictions))
# Out:
# Linear Regression Model Results :
# Root Mean Squared Error -> 0.06709541713112752
# R-score                 -> 0.7798633251833741
# Mean Absolute Error     -> 0.04527200000000001

# %%
print("Green Line  -> Test")
print("Orange Line -> Predicted")
fig = plt.figure(figsize = (25,10))
c = [i for i in range(1,101,1)]
plt.plot(c,y_test,color = 'green', linewidth = 2.5, label='Test')
plt.plot(c,rfr_predictions, color = 'orange', linewidth = 2.5, label='Predicted')
plt.grid(alpha = 0.4)
plt.legend()
fig.suptitle('Actual vs Predicted',size = 30)
# Out:
# Green Line  -> Test
# Orange Line -> Predicted
# Text(0.5, 0.98, 'Actual vs Predicted')

# %% [markdown]
# # KNeighborsRegressor

# %%
knr_model = KNeighborsRegressor()
knr_model.fit(x_train,y_train)
knr_predictions = knr_model.predict(x_test)
print("Linear Regression Model Results :")
print("Root Mean Squared Error ->",np.sqrt(mean_squared_error(y_test,knr_predictions)))
print("R-score                 ->",r2_score(y_test,knr_predictions))
print("Mean Absolute Error     ->",mean_absolute_error(y_test,knr_predictions))
# Out:
# Linear Regression Model Results :
# Root Mean Squared Error -> 0.06443011718133065
# R-score                 -> 0.7970053789731052
# Mean Absolute Error     -> 0.04513999999999999

# %%
print("Green Line  -> Test")
print("Orange Line -> Predicted")
fig = plt.figure(figsize = (25,10))
c = [i for i in range(1,101,1)]
plt.plot(c,y_test,color = 'green', linewidth = 2.5, label='Test')
plt.plot(c,knr_predictions, color = 'orange', linewidth = 2.5, label='Predicted')
plt.grid(alpha = 0.4)
plt.legend()
fig.suptitle('Actual vs Predicted',size = 30)
# Out:
# Green Line  -> Test
# Orange Line -> Predicted
# Text(0.5, 0.98, 'Actual vs Predicted')

# %% [markdown]
# # Important Features

# %%
classifier = RandomForestRegressor()
classifier.fit(X,Y)
feature_names = X.columns
importance_frame = pd.DataFrame()
importance_frame['Features'] = X.columns
importance_frame['Importance'] = classifier.feature_importances_
importance_frame = importance_frame.sort_values(by=['Importance'], ascending=True)

# %%
plt.figure(figsize = (10,8))
plt.barh([1,2,3,4,5,6,7], importance_frame['Importance'], align='center', alpha=1)
plt.yticks([1,2,3,4,5,6,7], importance_frame['Features'])
plt.xlabel('Importance',size=15)
plt.title('Feature Importances',size=20)
plt.show()

# %% [markdown]
# ## Importance of Features using Matplot Library

# %%
import matplotlib.pyplot as plt
import random

feature_importance = pd.DataFrame(sorted(zip(rfr_model.feature_importances_, X.columns)), columns=['Importance','Feature'])
plt.figure(figsize=(10, 6)) 
sns.barplot(x="Importance", y="Feature", data=feature_importance.sort_values(by="Importance", ascending=False))
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>
